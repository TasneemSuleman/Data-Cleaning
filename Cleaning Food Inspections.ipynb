# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Food_Inspections.csv')

# %%
df.head()
# Out:
#    Inspection ID                      DBA Name                      AKA Name  \
# 0        2229599                       FRESHII                       FRESHII
# 1        2229600     TAQUERIA  MAZAMITLA, INC.     TAQUERIA  MAZAMITLA, INC.
# 2        2229598                       FRESHII                       FRESHII
# 3        2229592              CIAO GOURMET T-1  CIAO GOURMET MARKET (T1 C16)
# 4        2229596  MOORE & ALLEYNE INCORPORATED             GOURMET JUNK FOOD
#
#    License #  Facility Type           Risk              Address     City  \
# 0  2309263.0     Restaurant  Risk 1 (High)  50 E WASHINGTON ST   CHICAGO
# 1  2327177.0     Restaurant  Risk 1 (High)  3610 W BELMONT AVE   CHICAGO
# 2  2626482.0     Restaurant  Risk 1 (High)  50 E WASHINGTON ST   CHICAGO
# 3    34207.0  Grocery Store   Risk 3 (Low)   11601 W TOUHY AVE   CHICAGO
# 4  2622601.0     Restaurant  Risk 1 (High)     8458 S GREEN ST   CHICAGO
#
# ...

# %%
df.shape
# Out:
# (176217, 17)

# %%
df.columns
# Out:
# Index(['Inspection ID', 'DBA Name', 'AKA Name', 'License #', 'Facility Type',
#        'Risk', 'Address', 'City', 'State', 'Zip', 'Inspection Date',
#        'Inspection Type', 'Results', 'Violations', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
df.columns = [c.replace(' ', '_') for c in df.columns]

# %%
df.columns
# Out:
# Index(['Inspection_ID', 'DBA_Name', 'AKA_Name', 'License_#', 'Facility_Type',
#        'Risk', 'Address', 'City', 'State', 'Zip', 'Inspection_Date',
#        'Inspection_Type', 'Results', 'Violations', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
df['Inspection_ID'].is_unique

#ID sabka unique hai toh kuch problem nahi h
# Out:
# True

# %%
# Operation 1: Categorize Risk Column as High medium or low

df.Risk.unique()
# Out:
# array(['Risk 1 (High)', 'Risk 3 (Low)', 'Risk 2 (Medium)', nan, 'All'],
#       dtype=object)

# %%
#Replace kiya values. All ko bhi high risk diya

df.replace({'Risk 1 (High)': 'High', 'Risk 3 (Low)': 'Low', 'Risk 2 (Medium)':'Medium', 'All':'High'})
# Out:
#         Inspection_ID                                           DBA_Name  \
# 0             2229599                                            FRESHII
# 1             2229600                          TAQUERIA  MAZAMITLA, INC.
# 2             2229598                                            FRESHII
# 3             2229592                                   CIAO GOURMET T-1
# 4             2229596                       MOORE & ALLEYNE INCORPORATED
# 5             2229586                                          TACO BELL
# 6             2108218                                       AREPA GEORGE
# 7             2229588                                       GOOSE ISLAND
# 8             2222870                                       HOTEL JULIAN
# 9             2108217  NORTHWEST INSTITUTE FOR CONTEMPORARY LEARNING,INC
# 10            2108216                                        JUDAH NORTH
# 11            2229585                             HOST INTERNATIONAL INC
# ...

# %%
df.DBA_Name.unique()
# Out:
# array(['FRESHII', 'TAQUERIA  MAZAMITLA, INC.', 'CIAO GOURMET T-1', ...,
#        'SAFAH FOOD & LIQUOR INC', 'RAINBOW GROCERY', 'MAKIA FOOD'],
#       dtype=object)

# %%
# Operation 2: Violations pe one hot encoding

#df.Violations.unique()

# %%
# Operation 3: Drop AKA Name - Kyuki redudant hai because DBA NAme diya hai

# %%
# Operation 4: Drop 'latitude' and 'longitude' kyuki 'location' column de rha hai values of latitude and longitude

# %%
#Operation 5: Drop State and Zip kyuki public state and zip se search nahi karta restaurants. Agar koi professional
# organization ko exact location search karna hi hai toh location ka field hai

#Yeh cleaning nahi karegi toh bhi chalega.

# %%
df['DBA_Name'].value_counts()


#Operation 6

#Replace similar values with one value. 'SUBWAY' aur 'Subway' and 'Subway Sandwiches' alag hai
# MCDONALD'S and MCDONALDS and MC DONALD'S alag hai

#Yeh DBA_Name ke liye hai

#Rows ko merge karne ke baad baki fields barabar merger kar.
#For example Violations for 'SUBWAY' aur 'Subway' and 'Subway Sandwiches' sab add hona chahiye.
# Out:
# SUBWAY                             2460
# DUNKIN DONUTS                      1260
# MCDONALD'S                          526
# 7-ELEVEN                            400
# MCDONALDS                           312
# CHIPOTLE MEXICAN GRILL              287
# POTBELLY SANDWICH WORKS LLC         250
# CORNER BAKERY CAFE                  223
# POTBELLY SANDWICH WORKS             216
# DUNKIN DONUTS/BASKIN ROBBINS        201
# FRESHII                             192
# DOMINO'S PIZZA                      186
# AU BON PAIN                         185
# WHOLE FOODS MARKET                  185
# SUBWAY SANDWICHES                   180
# SPORTSERVICE SOLDIER FIELD          176
# HAROLD'S CHICKEN SHACK              176
# KFC                                 165
# Subway                              160
# SEE THRU CHINESE KITCHEN            146
# SHARKS FISH & CHICKEN               137
# PIZZA HUT                           134
# MC DONALD'S                         130
# ...

# %%
df['Address'].value_counts()
# Out:
# 11601 W TOUHY AVE                2271
# 5700 S CICERO AVE                 459
# 500 W MADISON ST                  397
# 324 N LEAVITT ST                  369
# 100 W RANDOLPH ST                 290
# 131 N CLINTON ST                  284
# 2300 S THROOP ST                  275
# 333 W 35TH ST                     246
# 7601 S CICERO AVE                 238
# 600 E GRAND AVE                   234
# 222 W MERCHANDISE MART PLZ        222
# 1410 S MUSEUM CAMPUS DR           214
# 700 E GRAND AVE                   207
# 520 N MICHIGAN AVE                177
# 2002 S WENTWORTH AVE              170
# 1060 W ADDISON ST                 168
# 225 S CANAL ST                    162
# 233 N MICHIGAN AVE                154
# 233 S WACKER DR                   140
# 175 W JACKSON BLVD                133
# 835 N MICHIGAN AVE                118
# 800 N KEDZIE AVE                  117
# 201 N CLARK ST                    114
# 2637 S THROOP ST                  112
# 151 E WACKER DR                   110
# ...

# %%
df.columns[df.isna().any()].tolist()

#Yeh sab columns mein kahi na kahi null values hai.
# Out:
# ['AKA_Name',
#  'License_#',
#  'Facility_Type',
#  'Risk',
#  'City',
#  'State',
#  'Zip',
#  'Inspection_Type',
#  'Violations',
#  'Latitude',
#  'Longitude',
#  'Location']

# %%
indices = list(np.where(df['AKA_Name'].isna()))

# %%
print(type(indices))
# Out:
# <class 'list'>

# %%
print(indices)
# Out:
# [array([    25,    164,    231, ..., 176178, 176192, 176206])]

# %%
d = dict()
d = df.isnull().any(axis=1)

# %%
list_of_rows_to_drop = []
for i in range(len(d)):
    if(d[i]==True):
        list_of_rows_to_drop.append(i)

# %%
print(list_of_rows_to_drop)
# Out:
# [0, 8, 9, 10, 12, 17, 19, 21, 25, 26, 28, 31, 32, 38, 48, 51, 52, 53, 59, 64, 65, 70, 72, 73, 74, 76, 80, 83, 89, 91, 93, 95, 98, 104, 106, 108, 110, 111, 112, 118, 121, 127, 128, 137, 145, 147, 152, 153, 157, 162, 164, 168, 171, 177, 178, 179, 180, 181, 188, 191, 194, 195, 196, 197, 204, 208, 214, 215, 220, 223, 224, 225, 226, 227, 231, 237, 238, 239, 243, 249, 250, 253, 258, 262, 264, 265, 269, 272, 273, 274, 280, 285, 290, 303, 304, 307, 312, 313, 316, 317, 319, 321, 327, 337, 345, 353, 356, 363, 368, 369, 378, 382, 390, 392, 396, 400, 403, 405, 407, 409, 411, 418, 419, 425, 426, 429, 432, 433, 437, 441, 445, 450, 455, 456, 461, 462, 463, 465, 469, 471, 473, 477, 487, 491, 496, 503, 512, 527, 530, 533, 542, 550, 554, 556, 566, 569, 576, 577, 579, 580, 584, 586, 587, 595, 600, 616, 620, 621, 622, 626, 627, 629, 632, 635, 645, 647, 651, 655, 668, 669, 670, 671, 681, 683, 684, 687, 689, 691, 692, 695, 701, 705, 721, 729, 730, 737, 738, 741, 747, 752, 753, 760, 762, 766, 768, 769, 775
# ...

# %%
len(list_of_rows_to_drop)
# Out:
# 49039

# %%
df['Results'].value_counts()
# Out:
# Pass                    101551
# Fail                     34151
# Pass w/ Conditions       18357
# Out of Business          15428
# No Entry                  5304
# Not Ready                 1363
# Business Not Located        63
# Name: Results, dtype: int64

# %%
df['Facility_Type'].value_counts()
# Out:
# Restaurant                         117049
# Grocery Store                       23051
# School                              10914
# Bakery                               2588
# Daycare (2 - 6 Years)                2563
# Children's Services Facility         2303
# Daycare Above and Under 2 Years      1981
# Long Term Care                       1122
# Catering                             1034
# Mobile Food Dispenser                 832
# Liquor                                791
# Daycare Combo 1586                    767
# Mobile Food Preparer                  526
# Wholesale                             526
# Golden Diner                          484
# Hospital                              464
# TAVERN                                241
# Daycare (Under 2 Years)               215
# Special Event                         201
# Shared Kitchen User (Long Term)       187
# BANQUET HALL                          130
# GAS STATION                           109
# ...
